# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("rainfall_by_districts_2019.csv")

# %%
df.head()
# Out:
#   S.No      District  \
# 0    1       Chennai
# 1    2  Kancheepuram
# 2    3    Tiruvallur
# 3    4     Cuddalore
# 4    5    Villupuram
#
#    Actual Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              449.7
# 1                                              488.5
# 2                                              498.7
# 3                                              465.7
# 4                                              441.3
#
#    Normal Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              439.1
# 1                                              490.8
# 2                                              451.6
# 3                                              383.1
# 4                                              408.3
#
#    Actual Rainfall in North East Monsoon (October'17 to December'17) in mm  \
# 0                                              937.8
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# S.No                                                                       0
# District                                                                   0
# Actual Rainfall in South West Monsoon (June'17 to September'17) in mm      0
# Normal Rainfall in South West Monsoon (June'17 to September'17) in mm      0
# Actual Rainfall in North East Monsoon (October'17 to December'17) in mm    0
# Normal Rainfall in North East Monsoon (October'17 to December'17) in mm    0
# Actual Rainfall in Winter Season (January'18 to and February'18) in mm     0
# Normal Rainfall in Winter Season (January'18 to and February'18) in mm     0
# Actual Rainfall in Hot Weather Season (March'18 to May'18) in mm           0
# Normal Rainfall in Hot Weather Season (March'18 to May'18) in mm           0
# Total Actual Rainfall (June'17 to May'18) in mm                            0
# Total Normal Rainfall (June'17 to May'18) in mm                            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['S.No', 'District',
#        'Actual Rainfall in South West Monsoon (June'17 to September'17) in mm',
#        'Normal Rainfall in South West Monsoon (June'17 to September'17) in mm',
#        'Actual Rainfall in North East Monsoon (October'17 to December'17) in mm',
#        'Normal Rainfall in North East Monsoon (October'17 to December'17) in mm',
#        'Actual Rainfall in Winter Season (January'18 to and February'18) in mm',
#        'Normal Rainfall in Winter Season (January'18 to and February'18) in mm',
#        'Actual Rainfall in Hot Weather Season (March'18 to May'18) in mm',
#        'Normal Rainfall in Hot Weather Season (March'18 to May'18) in mm',
#        'Total Actual Rainfall (June'17 to May'18) in mm',
#        'Total Normal Rainfall (June'17 to May'18) in mm'],
#       dtype='object')

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 12 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   S.No                                                                     33 non-null     object
#  1   District                                                                 33 non-null     object
#  2   Actual Rainfall in South West Monsoon (June'17 to September'17) in mm    33 non-null     float64
#  3   Normal Rainfall in South West Monsoon (June'17 to September'17) in mm    33 non-null     float64
#  4   Actual Rainfall in North East Monsoon (October'17 to December'17) in mm  33 non-null     float64
#  5   Normal Rainfall in North East Monsoon (October'17 to December'17) in mm  33 non-null     float64
# ...

# %%
df['District']
# Out:
# 0             Chennai
# 1        Kancheepuram
# 2          Tiruvallur
# 3           Cuddalore
# 4          Villupuram
# 5             Vellore
# 6      Tiruvannamalai
# 7               Salem
# 8            Namakkal
# 9          Dharmapuri
# 10        Krishnagiri
# 11           Tiruppur
# 12         Coimbatore
# 13              Erode
# 14    Tiruchirappalli
# 15              Karur
# 16         Perambalur
# 17        Pudukkottai
# 18          Thanjavur
# 19          Tiruvarur
# 20       Nagapattinam
# 21            Madurai
# 22              Theni
# 23           Dindigul
# 24     Ramanathapuram
# 25       Virudhunagar
# 26          Sivaganga
# 27        Tirunelveli
# 28        Thoothukudi
# 29       The Nilgiris
# 30           Ariyalur
# 31      Kanniyakumari
# 32      State Average
# Name: District, dtype: object

# %%
df.size
# Out:
# 396

# %%
numeric_columns = ["Total Actual Rainfall (June'17 to May'18) in mm","Total Normal Rainfall (June'17 to May'18) in mm" ]
for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],kde = True,bins = 20)

# %%
numeric_columns = ["Actual Rainfall in South West Monsoon (June'17 to September'17) in mm","Actual Rainfall in North East Monsoon (October'17 to December'17) in mm",
"Actual Rainfall in Winter Season (January'18 to and February'18) in mm","Actual Rainfall in Hot Weather Season (March'18 to May'18) in mm" ]
for col in numeric_columns:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col],kde = True,bins = 20)

# %%
numeric_columns = ["Normal Rainfall in South West Monsoon (June'17 to September'17) in mm", "Normal Rainfall in North East Monsoon (October'17 to December'17) in mm", "Normal Rainfall in Winter Season (January'18 to and February'18) in mm","Normal Rainfall in Hot Weather Season (March'18 to May'18) in mm"]
for col in numeric_columns:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col],kde = True,bins = 20)

# %%
new_names = {
    "Actual Rainfall in South West Monsoon (June\'17 to September\'17) in mm": "Actual SW",
    "Normal Rainfall in South West Monsoon (June\'17 to September\'17) in mm": "Normal SW",
    "Actual Rainfall in North East Monsoon (October'17 to December'17) in mm": "Actual NE",
    "Normal Rainfall in North East Monsoon (October'17 to December'17) in mm": "Normal NE", 
    "Actual Rainfall in Winter Season (January'18 to and February'18) in mm" : "Actual Winter",
    "Normal Rainfall in Winter Season (January'18 to and February'18) in mm" : "Normal Winter",
    "Actual Rainfall in Hot Weather Season (March'18 to May'18) in mm" : "Actual Hot",
    "Normal Rainfall in Hot Weather Season (March'18 to May'18) in mm" : "Normal Hot",
    "Total Actual Rainfall (June'17 to May'18) in mm" : "Total Actual",
    "Total Normal Rainfall (June'17 to May'18) in mm" : "Total Normal", 
}

# 2. Rename the columns
df = df.rename(columns=new_names)

# 3. Re-run your correlation and heatmap (this time with clean names!)
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df_encoded = pd.get_dummies(df,drop_first= True)
df_encoded
# Out:
#     Actual SW  Normal SW  Actual NE  Normal NE  Actual Winter  Normal Winter  \
# 0       449.7      439.1      937.8      789.9            3.1           36.7
# 1       488.5      490.8      672.6      641.8            4.4           29.1
# 2       498.7      451.6      677.8      589.3            8.1           31.5
# 3       465.7      383.1      775.9      697.8           55.0           44.1
# 4       441.3      408.3      535.7      499.1           10.5           28.2
# 5       573.7      466.1      338.8      348.7            9.8           14.9
# 6       621.9      468.1      524.9      446.5           34.9           26.5
# 7       484.7      440.6      341.9      370.5           15.4           16.0
# 8       379.1      339.3      256.5      291.6           26.8           13.9
# 9       402.4      393.4      254.6      330.1            1.4           18.2
# 10      525.1      399.0      329.7      289.4            1.3           10.7
# ...

# %%
df_encoded = df_encoded.astype(int)
df_encoded.head()
# Out:
#    Actual SW  Normal SW  Actual NE  Normal NE  Actual Winter  Normal Winter  \
# 0        449        439        937        789              3             36
# 1        488        490        672        641              4             29
# 2        498        451        677        589              8             31
# 3        465        383        775        697             55             44
# 4        441        408        535        499             10             28
#
#    Actual Hot  Normal Hot  Total Actual  Total Normal  ...  \
# 0           2          58          1393          1324  ...
# 1          14          66          1180          1227  ...
# 2          17          67          1202          1139  ...
# 3          14          81          1311          1206  ...
# 4          24          76          1011          1011  ...
#
#    District_Thoothukudi  District_Tiruchirappalli  District_Tirunelveli  \
# 0                     0                         0                     0
# ...

# %%
df_encoded.columns
# Out:
# Index(['Actual SW', 'Normal SW', 'Actual NE', 'Normal NE', 'Actual Winter',
#        'Normal Winter', 'Actual Hot', 'Normal Hot', 'Total Actual',
#        'Total Normal', 'S.No_10', 'S.No_11', 'S.No_12', 'S.No_13', 'S.No_14',
#        'S.No_15', 'S.No_16', 'S.No_17', 'S.No_18', 'S.No_19', 'S.No_2',
#        'S.No_20', 'S.No_21', 'S.No_22', 'S.No_23', 'S.No_24', 'S.No_25',
#        'S.No_26', 'S.No_27', 'S.No_28', 'S.No_29', 'S.No_3', 'S.No_30',
#        'S.No_31', 'S.No_32', 'S.No_4', 'S.No_5', 'S.No_6', 'S.No_7', 'S.No_8',
#        'S.No_9', 'S.No_Average', 'District_Chennai', 'District_Coimbatore',
#        'District_Cuddalore', 'District_Dharmapuri', 'District_Dindigul',
#        'District_Erode', 'District_Kancheepuram', 'District_Kanniyakumari',
#        'District_Karur', 'District_Krishnagiri', 'District_Madurai',
#        'District_Nagapattinam', 'District_Namakkal', 'District_Perambalur',
#        'District_Pudukkottai', 'District_Ramanathapuram', 'District_Salem',
# ...

# %%
# Create a list of columns that start with 'S.No'
s_no_cols = [col for col in df_encoded.columns if col.startswith('S.No')] 

# Drop the selected columns
df_encoded.drop(columns=s_no_cols, inplace=True)

# Verify
df_encoded.columns
# Out:
# Index(['Actual SW', 'Normal SW', 'Actual NE', 'Normal NE', 'Actual Winter',
#        'Normal Winter', 'Actual Hot', 'Normal Hot', 'Total Actual',
#        'Total Normal', 'District_Chennai', 'District_Coimbatore',
#        'District_Cuddalore', 'District_Dharmapuri', 'District_Dindigul',
#        'District_Erode', 'District_Kancheepuram', 'District_Kanniyakumari',
#        'District_Karur', 'District_Krishnagiri', 'District_Madurai',
#        'District_Nagapattinam', 'District_Namakkal', 'District_Perambalur',
#        'District_Pudukkottai', 'District_Ramanathapuram', 'District_Salem',
#        'District_Sivaganga', 'District_State Average', 'District_Thanjavur',
#        'District_The Nilgiris', 'District_Theni', 'District_Thoothukudi',
#        'District_Tiruchirappalli', 'District_Tirunelveli', 'District_Tiruppur',
#        'District_Tiruvallur', 'District_Tiruvannamalai', 'District_Tiruvarur',
#        'District_Vellore', 'District_Villupuram', 'District_Virudhunagar'],
# ...

# %%
sns.histplot(df["Total Normal"])
# Out:
# <Axes: xlabel='Total Normal', ylabel='Count'>

# %%
sns.histplot(df["Total Actual"])
# Out:
# <Axes: xlabel='Total Actual', ylabel='Count'>

# %%
from scipy.stats import pearsonr
# Pearson Correlation Calculation
# List of features to check against target
selected_features = [
    'District_Chennai', 'District_Coimbatore',
       'District_Cuddalore', 'District_Dharmapuri', 'District_Dindigul',
       'District_Erode', 'District_Kancheepuram', 'District_Kanniyakumari',
       'District_Karur', 'District_Krishnagiri', 'District_Madurai',
       'District_Nagapattinam', 'District_Namakkal', 'District_Perambalur',
       'District_Pudukkottai', 'District_Ramanathapuram', 'District_Salem',
       'District_Sivaganga', 'District_State Average', 'District_Thanjavur',
       'District_The Nilgiris', 'District_Theni', 'District_Thoothukudi',
       'District_Tiruchirappalli', 'District_Tirunelveli', 'District_Tiruppur',
       'District_Tiruvallur', 'District_Tiruvannamalai', 'District_Tiruvarur',
       'District_Vellore', 'District_Villupuram', 'District_Virudhunagar'
]

correlations = {
    feature: pearsonr(df_encoded[feature], df_encoded['Total Normal'])[0]
    for feature in selected_features
}
correlation_df = pd.DataFrame(list(correlations.items()), columns=['Feature', 'Pearson Correlation'])
correlation_df.sort_values(by='Pearson Correlation', ascending=False)
# Out:
#                      Feature  Pearson Correlation
# 20     District_The Nilgiris             0.446985
# 11     District_Nagapattinam             0.344462
# 0           District_Chennai             0.289625
# 7     District_Kanniyakumari             0.272140
# 6      District_Kancheepuram             0.212534
# 2         District_Cuddalore             0.195845
# 28        District_Tiruvarur             0.169618
# 26       District_Tiruvallur             0.142597
# 27   District_Tiruvannamalai             0.063917
# 19        District_Thanjavur             0.042459
# 30       District_Villupuram             0.040869
# 16            District_Salem             0.029743
# 18    District_State Average             0.000337
# 29          District_Vellore            -0.018737
# 4          District_Dindigul            -0.023505
# 10          District_Madurai            -0.025889
# 3        District_Dharmapuri            -0.045758
# 14      District_Pudukkottai            -0.057679
# ...

# %%
cat_features = [
     'District_Chennai', 'District_Coimbatore', 'District_Cuddalore', 'District_Dharmapuri',
    'District_Dindigul', 'District_Erode', 'District_Kancheepuram', 'District_Kanniyakumari',
    'District_Karur', 'District_Krishnagiri', 'District_Madurai', 'District_Nagapattinam',
    'District_Namakkal', 'District_Perambalur', 'District_Pudukkottai', 'District_Ramanathapuram',
    'District_Salem', 'District_Sivaganga', 'District_State Average', 'District_Thanjavur',
    'District_The Nilgiris', 'District_Theni', 'District_Thoothukudi', 'District_Tiruchirappalli',
    'District_Tirunelveli', 'District_Tiruvallur', 'District_Tiruvannamalai', 'District_Tiruvarur',
    'District_Vellore', 'District_Villupuram', 'District_Virudhunagar'
]
from scipy.stats import chi2_contingency
import pandas as pd

alpha = 0.05

df_encoded['Total Actual'] = pd.qcut(df_encoded['Total Actual'], q=4, labels=False)
chi2_results = {}

for col in cat_features:
    contingency = pd.crosstab(df_encoded[col], df_encoded['Total Actual'])
    chi2_stat, p_val, _, _ = chi2_contingency(contingency)
    decision = 'Reject Null (Keep Feature)' if p_val < alpha else 'Accept Null (Drop Feature)'
    chi2_results[col] = {
        'chi2_statistic': chi2_stat,
        'p_value': p_val,
        'Decision': decision
    }

chi2_df = pd.DataFrame(chi2_results).T
chi2_df = chi2_df.sort_values(by='p_value')
chi2_df
# Out:
#                          chi2_statistic   p_value                    Decision
# District_Chennai               3.222656  0.358553  Accept Null (Drop Feature)
# District_Vellore               3.222656  0.358553  Accept Null (Drop Feature)
# District_Tiruvarur             3.222656  0.358553  Accept Null (Drop Feature)
# District_Tiruvannamalai        3.222656  0.358553  Accept Null (Drop Feature)
# District_Tiruvallur            3.222656  0.358553  Accept Null (Drop Feature)
# District_Tirunelveli           3.222656  0.358553  Accept Null (Drop Feature)
# District_Theni                 3.222656  0.358553  Accept Null (Drop Feature)
# District_The Nilgiris          3.222656  0.358553  Accept Null (Drop Feature)
# District_Thanjavur             3.222656  0.358553  Accept Null (Drop Feature)
# District_State Average         3.222656  0.358553  Accept Null (Drop Feature)
# District_Sivaganga             3.222656  0.358553  Accept Null (Drop Feature)
# ...

# %%
df['District'] = df['District'].astype('category').cat.codes

# %%
X = df.drop(["Total Actual"], axis=1)
y = df["Total Actual"].copy()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
 X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
X_train.dtypes
# Out:
# S.No              object
# District            int8
# Actual SW        float64
# Normal SW        float64
# Actual NE        float64
# Normal NE        float64
# Actual Winter    float64
# Normal Winter    float64
# Actual Hot       float64
# Normal Hot       float64
# Total Normal     float64
# dtype: object

# %%
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
# Align columns
X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)
# Then scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier(),
    "SVM (RBF Kernel)": SVC(probability=True)
}

# %%
results = []

# %%
y_train.head()
y_train.dtype
# Out:
# dtype('float64')

# %%
model = LinearRegression()
model.fit(X_train_scaled, y_train)

y_predict = model.predict(X_test_scaled)

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("📊 Model Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.3f}")
print(f"Mean Squared Error (MSE): {mse:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
print(f"R² Score: {r2:.3f}")
# Out:
# 📊 Model Evaluation Metrics:
# Mean Absolute Error (MAE): 101.645
# Mean Squared Error (MSE): 13482.911
# Root Mean Squared Error (RMSE): 116.116
# R² Score: 0.713

# %%
df.columns
# Out:
# Index(['S.No', 'District', 'Actual SW', 'Normal SW', 'Actual NE', 'Normal NE',
#        'Actual Winter', 'Normal Winter', 'Actual Hot', 'Normal Hot',
#        'Total Actual', 'Total Normal'],
#       dtype='object')

# %%
X = df[['Normal Winter','Actual Winter' ,'Actual SW','Actual NE' ]]
y = df['Total Actual']

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)

import joblib
joblib.dump(model, 'rainfalls_model.pkl')
# Out:
# ['rainfalls_model.pkl']

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, color='blue', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.show()

# %%
residuals = y_test - y_pred

plt.figure(figsize=(6,4))
plt.scatter(y_pred, residuals, color='purple', alpha=0.6)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
